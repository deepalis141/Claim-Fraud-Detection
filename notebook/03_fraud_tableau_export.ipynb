# %%
DASHBOARD_DIR = PROJECT_ROOT / "dashboard"
DASHBOARD_DIR.mkdir(exist_ok=True)

dashboard_df = fraud_results.copy()
dashboard_df["is_fraud"] = dashboard_df["actual_class"]

dashboard_path = DASHBOARD_DIR / "fraud_dashboard_data.csv"
dashboard_df.to_csv(dashboard_path, index=True)  # keep index as transaction ID
print("Saved dashboard data to:", dashboard_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 DASHBOARD_DIR = PROJECT_ROOT / "dashboard"
#       2 DASHBOARD_DIR.mkdir(exist_ok=True)
#       4 dashboard_df = fraud_results.copy()
#
# NameError: name 'PROJECT_ROOT' is not defined

# %%
import pandas as pd

df = pd.read_csv("/Users/Deepali/Downloads/buju/Fraud Detection Project/dashboard/fraud_dashboard_data.csv")
df["claim_id"] = range(1, len(df) + 1)
df.to_csv("fraud_dashboard_data_clean.csv", index=False)
